# %%
# -*- coding: utf-8 -*-
#!/usr/bin/env python3
from __future__ import (absolute_import, division, print_function,unicode_literals)
import datetime
from datetime import datetime
import json
import numpy as np
import pandas as pd
import os.path
import sys
import pytz
import time
from os.path import exists
import backtrader as bt
import ray

# %%
class TestSizer(bt.Sizer):
    params = (('stake', 1),)    
    def _getsizing(self, comminfo, cash, data, isbuy):        
        if isbuy:          
            return self.p.stake        
        position = self.broker.getposition(data)        
        if not position.size:            
            return 0        
        else:            
            return position.size        
        return self.p.stake

class TestStrategy(bt.Strategy):
    params = ( ('maperiod', 15),  ('printlog', False), )   
    def log(self, txt, dt=None, doprint=False):            
        dt = dt or self.datas[0].datetime.date(0)           
        print('%s, %s' % (dt.isoformat(), txt))    

    def __init__(self):        

        self.dataclose = self.datas[0].close      
        self.datahigh = self.datas[0].high        
        self.datalow = self.datas[0].low     

        self.order = None      
        self.buyprice = 0      
        self.buycomm = 0      
        self.newstake = 0      
        self.buytime = 0       
        # 参数计算，唐奇安通道上轨、唐奇安通道下轨、ATR        
        self.DonchianHi = bt.indicators.Highest(self.datahigh(-1), period=20, subplot=False)        
        self.DonchianLo = bt.indicators.Lowest(self.datalow(-1), period=10, subplot=False)       
        self.TR = bt.indicators.Max((self.datahigh(0)- self.datalow(0)), abs(self.dataclose(-1) -   self.datahigh(0)), abs(self.dataclose(-1)  - self.datalow(0) ))        
        self.ATR = bt.indicators.SimpleMovingAverage(self.TR, period=14, subplot=True)       
        # 唐奇安通道上轨突破、唐奇安通道下轨突破       
        self.CrossoverHi = bt.ind.CrossOver(self.dataclose(0), self.DonchianHi)        
        self.CrossoverLo = bt.ind.CrossOver(self.dataclose(0), self.DonchianLo)    
    def notify_order(self, order):        
        if order.status in [order.Submitted, order.Accepted]:            
            return

        if order.status in [order.Completed]:            
            if order.isbuy():               
                self.log(                    
                'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %                   
                (order.executed.price,
                order.executed.value,
                order.executed.comm),doprint=True)              
                self.buyprice = order.executed.price              
                self.buycomm = order.executed.comm            
            else:             
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %                        
                     (order.executed.price,
                     order.executed.value,
                     order.executed.comm),doprint=True)                             
                self.bar_executed = len(self)       
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:           
            self.log('Order Canceled/Margin/Rejected')        
        self.order = None    

    def notify_trade(self, trade):      
        if not trade.isclosed:
            return        
        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' % (trade.pnl, trade.pnlcomm)) 

    def next(self): 
        if self.order:
            return        
        #入场        
        if self.CrossoverHi > 0 and self.buytime == 0:                                 
            self.newstake = self.broker.getvalue() * 0.01 / self.ATR            
            self.newstake = int(self.newstake / 100) * 100                             
            self.sizer.p.stake = self.newstake            
            self.buytime = 1            
            self.order = self.buy()        
        #加仓        
        elif self.datas[0].close >self.buyprice+0.5*self.ATR[0] and self.buytime > 0 and self.buytime < 5:           
            self.newstake = self.broker.getvalue() * 0.01 / self.ATR            
            self.newstake = int(self.newstake / 100) * 100            
            self.sizer.p.stake = self.newstake            
            self.order = self.buy()           
            self.buytime = self.buytime + 1        
        #出场        
        elif self.CrossoverLo < 0 and self.buytime > 0:            
            self.order = self.sell()            
            self.buytime = 0        
        #止损        
        elif self.datas[0].close < (self.buyprice - 2*self.ATR[0]) and self.buytime > 0:           
            self.order = self.sell()
            self.buytime = 0   
    def stop(self):        
        self.log('(MA Period %2d) Ending Value %.2f' % (15, self.broker.getvalue()), doprint=True)

# %%
@ray.remote    
def BackTest(code):
    cerebro = bt.Cerebro()
    # 增加一个策略
    cerebro.addstrategy(TestStrategy)

    #获取数据
    start_date = datetime(2010, 1, 1)  
    end_date = datetime(2022, 12, 30)  
    
    filename = '/home/shared/data/'+code +'.csv'
    dest_filename = '/home/shared/result' + filename
    stock_hfq_df = pd.read_csv(filename)
    stock_hfq_df.index = stock_hfq_df['date'].apply(lambda x: datetime.strptime(x,'%Y-%m-%d'))
    stock_hfq_df = stock_hfq_df[['open','close','high','low','volume']]
    
    data = bt.feeds.PandasData(dataname=stock_hfq_df, fromdate=start_date, todate=end_date)  # 加载数据
    cerebro.adddata(data)  # 将数据传入回测系统

    cerebro.broker.setcash(1000000.0)
    cerebro.broker.setcommission(commission=0.0002)# 设置交易手续费为 0.02%
    # 设置买入策略    
    cerebro.addsizer(TestSizer)
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    cerebro.run()

    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
    
    f = open("./result.txt", "a")
    f.write('Final Portfolio Value: %.2f\n' % cerebro.broker.getvalue())
    f.write('Return: %.4f' % (float(cerebro.broker.getvalue())/1e6 - 1))
    f.close()

# %%
data_dir = '/home/shared/data/'
industry = 'bank'
txtname = data_dir+industry + '.txt'
stock_list = []

# 创建Ray集群
ray.init(address="ray://fsi-ray-head-svc.fsi-ray.svc.cluster.local:10001",runtime_env={"pip": ["backtrader"]} )  # Initialize Ray
# Out:
# SIGTERM handler is not set because current thread is not the main thread.
# 2024-12-19 07:55:45,770	WARNING utils.py:1591 -- Python patch version mismatch: The cluster was started with:
#     Ray: 2.35.0
#     Python: 3.11.9
# This process on Ray Client was started with:
#     Ray: 2.35.0
#     Python: 3.11.8
# ClientContext(dashboard_url='100.64.91.12:8265', python_version='3.11.9', ray_version='2.35.0', ray_commit='ba24879ff81c8c5fd77acae435ee4a1d0b3d9e0c', _num_clients=3, _context_to_restore=<ray.util.client._ClientContext object at 0x7fba55179790>, protocol_version=None)
# (BackTest pid=29855, ip=100.64.248.190) Starting Portfolio Value: 1000000.00
# (BackTest pid=40350) Starting Portfolio Value: 1000000.00
# (BackTest pid=40350) 2022-03-21, BUY EXECUTED, Price: 5.86, Cost: 161736.00, Comm 32.35
# (BackTest pid=40350) 2022-03-23, BUY EXECUTED, Price: 5.96, Cost: 150192.00, Comm 30.04
# (BackTest pid=40350) 2022-04-06, BUY EXECUTED, Price: 6.25, Cost: 158125.00, Comm 31.63
# (BackTest pid=40350) 2022-04-19, SELL EXECUTED, Price: 5.32, Cost: 470053.00, Comm 83.10
# (BackTest pid=40350) 2022-04-19, OPERATION PROFIT, GROSS -54561.00, NET -54738.11
# (BackTest pid=40350) 2022-06-15, BUY EXECUTED, Price: 5.40, Cost: 314280.00, Comm 62.86
# (BackTest pid=40350) 2022-06-16, BUY EXECUTED, Price: 5.30, Cost: 261820.00, Comm 52.36
# (BackTest pid=40350) 2022-07-04, SELL EXECUTED, Price: 4.83, Cost: 576100.00, Comm 103.94
# (BackTest pid=29855, ip=100.64.248.190) 2022-09-21, SELL EXECUTED, Price: 12.31, Cost: 809880.00, Comm 155.35
# (BackTest pid=29855, ip=100.64.248.190) 2022-09-21, OPERATION PROFIT, GROSS -33119.00, NET -33436.33
# (BackTest pid=29855, ip=100.64.248.190) 2022-11-15, BUY EXECUTED, Price: 11.86, Cost: 314290.00, Comm 62.86
# (BackTest pid=29855, ip=100.64.248.190) 2022-11-28, BUY EXECUTED, Price: 11.90, Cost: 267750.00, Comm 53.55
# (BackTest pid=29855, ip=100.64.248.190) 2022-11-30, BUY EXECUTED, Price: 12.90, Cost: 246390.00, Comm 49.28
# (BackTest pid=29855, ip=100.64.248.190) 2022-12-06, Order Canceled/Margin/Rejected
# (BackTest pid=29855, ip=100.64.248.190) 2022-12-07, Order Canceled/Margin/Rejected
# (BackTest pid=29855, ip=100.64.248.190) 2022-12-21, SELL EXECUTED, Price: 12.85, Cost: 828430.00, Comm 175.02
# (BackTest pid=29855, ip=100.64.248.190) 2022-12-21, OPERATION PROFIT, GROSS 46655.00, NET 46314.30
# (BackTest pid=29855, ip=100.64.248.190) 2022-12-27, (MA Period 15) Ending Value 887628.00
# (BackTest pid=29855, ip=100.64.248.190) Final Portfolio Value: 887628.00
# (BackTest pid=29855, ip=100.64.248.190) Starting Portfolio Value: 1000000.00
# (BackTest pid=40350) 2010-07-13, BUY EXECUTED, Price: 12.00, Cost: 274800.00, Comm 54.96
# (BackTest pid=40350) 2010-07-23, BUY EXECUTED, Price: 12.39, Cost: 308511.00, Comm 61.70
# (BackTest pid=40350) 2010-07-29, BUY EXECUTED, Price: 12.62, Cost: 315500.00, Comm 63.10
# (BackTest pid=40350) 2010-08-11, SELL EXECUTED, Price: 11.86, Cost: 898811.00, Comm 172.68
# (BackTest pid=40350) 2010-08-11, OPERATION PROFIT, GROSS -35403.00, NET -35755.44
# (BackTest pid=40350) 2010-09-02, BUY EXECUTED, Price: 13.19, Cost: 294137.00, Comm 58.83
# (BackTest pid=40350) 2010-09-07, BUY EXECUTED, Price: 13.45, Cost: 291865.00, Comm 58.37
# (BackTest pid=40350) 2010-09-17, SELL EXECUTED, Price: 12.33, Cost: 586002.00, Comm 108.50
# (BackTest pid=40350) 2010-09-17, OPERATION PROFIT, GROSS -43482.00, NET -43707.70
# (BackTest pid=40350) 2010-10-18, BUY EXECUTED, Price: 14.36, Cost: 255608.00, Comm 51.12
# (BackTest pid=40350) 2010-10-20, BUY EXECUTED, Price: 14.99, Cost: 239840.00, Comm 47.97
# (BackTest pid=40350) 2010-11-11, SELL EXECUTED, Price: 13.72, Cost: 495448.00, Comm 92.75
# (BackTest pid=40350) 2010-11-11, OPERATION PROFIT, GROSS -31712.00, NET -31903.84
# (BackTest pid=40350) 2011-01-10, BUY EXECUTED, Price: 13.05, Cost: 199665.00, Comm 39.93
# (BackTest pid=40350) 2011-01-12, BUY EXECUTED, Price: 13.35, Cost: 206925.00, Comm 41.38
# (BackTest pid=40350) 2011-01-19, SELL EXECUTED, Price: 12.32, Cost: 406590.00, Comm 75.89
# (BackTest pid=40350) 2011-01-19, OPERATION PROFIT, GROSS -27134.00, NET -27291.21
# (BackTest pid=40350) 2011-03-04, BUY EXECUTED, Price: 13.43, Cost: 286059.00, Comm 57.21
# (BackTest pid=40350) 2011-04-06, BUY EXECUTED, Price: 13.70, Cost: 352090.00, Comm 70.42
# (BackTest pid=40350) 2011-04-29, SELL EXECUTED, Price: 13.21, Cost: 638149.00, Comm 124.17
# (BackTest pid=40350) 2011-04-29, OPERATION PROFIT, GROSS -17279.00, NET -17530.80
# (BackTest pid=40350) 2011-10-26, BUY EXECUTED, Price: 9.75, Cost: 322725.00, Comm 64.55
# (BackTest pid=40350) 2011-10-31, BUY EXECUTED, Price: 9.93, Cost: 313788.00, Comm 62.76
# (BackTest pid=40350) 2011-11-03, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2011-11-10, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2011-11-15, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2011-11-17, SELL EXECUTED, Price: 9.75, Cost: 636513.00, Comm 126.17
# (BackTest pid=40350) 2011-11-17, OPERATION PROFIT, GROSS -5688.00, NET -5941.47
# (BackTest pid=40350) 2012-01-30, BUY EXECUTED, Price: 9.81, Cost: 315882.00, Comm 63.18
# (BackTest pid=40350) 2012-02-06, BUY EXECUTED, Price: 10.00, Cost: 328000.00, Comm 65.60
# (BackTest pid=40350) 2012-02-27, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2012-02-28, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2012-02-29, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2012-03-08, SELL EXECUTED, Price: 9.79, Cost: 643882.00, Comm 127.27
# (BackTest pid=40350) 2012-03-08, OPERATION PROFIT, GROSS -7532.00, NET -7788.05
# (BackTest pid=40350) 2012-04-23, BUY EXECUTED, Price: 10.06, Cost: 310854.00, Comm 62.17
# (BackTest pid=40350) 2012-04-25, BUY EXECUTED, Price: 10.57, Cost: 268478.00, Comm 53.70
# (BackTest pid=40350) 2012-04-26, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2012-05-15, SELL EXECUTED, Price: 10.12, Cost: 579332.00, Comm 113.95
# (BackTest pid=40350) 2012-05-15, OPERATION PROFIT, GROSS -9576.00, NET -9805.82
# (BackTest pid=40350) 2012-12-10, BUY EXECUTED, Price: 9.18, Cost: 305694.00, Comm 61.14
# (BackTest pid=40350) 2012-12-11, BUY EXECUTED, Price: 9.27, Cost: 298494.00, Comm 59.70
# (BackTest pid=40350) 2012-12-17, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2012-12-18, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2012-12-19, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2013-02-22, SELL EXECUTED, Price: 11.03, Cost: 604188.00, Comm 144.49
# (BackTest pid=40350) 2013-02-22, OPERATION PROFIT, GROSS 118277.00, NET 118011.67
# (BackTest pid=40350) 2013-05-29, BUY EXECUTED, Price: 10.94, Cost: 396028.00, Comm 79.21
# (BackTest pid=40350) 2013-06-06, SELL EXECUTED, Price: 10.35, Cost: 396028.00, Comm 74.93
# (BackTest pid=40350) 2013-06-06, OPERATION PROFIT, GROSS -21358.00, NET -21512.14
# (BackTest pid=40350) 2013-09-10, BUY EXECUTED, Price: 9.47, Cost: 339026.00, Comm 67.81
# (BackTest pid=40350) 2013-09-13, BUY EXECUTED, Price: 9.71, Cost: 307807.00, Comm 61.56
# (BackTest pid=40350) 2013-09-26, SELL EXECUTED, Price: 8.95, Cost: 646833.00, Comm 120.82
# (BackTest pid=40350) 2013-09-26, OPERATION PROFIT, GROSS -42708.00, NET -42958.19
# (BackTest pid=40350) 2013-10-29, BUY EXECUTED, Price: 9.48, Cost: 366876.00, Comm 73.38
# (BackTest pid=40350) 2013-11-14, SELL EXECUTED, Price: 8.76, Cost: 366876.00, Comm 67.80
# (BackTest pid=40350) 2013-11-14, OPERATION PROFIT, GROSS -27864.00, NET -28005.18
# (BackTest pid=40350) 2013-12-03, BUY EXECUTED, Price: 9.38, Cost: 342370.00, Comm 68.47
# (BackTest pid=40350) 2013-12-06, BUY EXECUTED, Price: 9.52, Cost: 389368.00, Comm 77.87
# (BackTest pid=40350) 2013-12-23, SELL EXECUTED, Price: 9.14, Cost: 731738.00, Comm 141.49
# (BackTest pid=40350) 2013-12-23, OPERATION PROFIT, GROSS -24302.00, NET -24589.83
# (BackTest pid=40350) 2014-02-20, BUY EXECUTED, Price: 9.45, Cost: 358155.00, Comm 71.63
# (BackTest pid=40350) 2014-02-25, SELL EXECUTED, Price: 8.79, Cost: 358155.00, Comm 66.63
# (BackTest pid=40350) 2014-02-25, OPERATION PROFIT, GROSS -25014.00, NET -25152.26
# (BackTest pid=40350) 2014-04-09, BUY EXECUTED, Price: 9.11, Cost: 384442.00, Comm 76.89
# (BackTest pid=40350) 2014-05-13, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2014-06-05, SELL EXECUTED, Price: 8.91, Cost: 384442.00, Comm 75.20
# (BackTest pid=40350) 2014-06-05, OPERATION PROFIT, GROSS -8440.00, NET -8592.09
# (BackTest pid=40350) 2014-06-16, BUY EXECUTED, Price: 9.17, Cost: 686833.00, Comm 137.37
# (BackTest pid=40350) 2014-06-17, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2014-07-14, SELL EXECUTED, Price: 8.70, Cost: 686833.00, Comm 130.33
# (BackTest pid=40350) 2014-07-14, OPERATION PROFIT, GROSS -35203.00, NET -35470.69
# (BackTest pid=40350) 2014-07-29, BUY EXECUTED, Price: 9.89, Cost: 409446.00, Comm 81.89
# (BackTest pid=40350) 2014-08-01, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2014-08-05, BUY EXECUTED, Price: 10.03, Cost: 323969.00, Comm 64.79
# (BackTest pid=40350) 2014-08-15, SELL EXECUTED, Price: 9.61, Cost: 733415.00, Comm 141.65
# (BackTest pid=40350) 2014-08-15, OPERATION PROFIT, GROSS -25158.00, NET -25446.33
# (BackTest pid=40350) 2014-09-30, BUY EXECUTED, Price: 10.17, Cost: 408834.00, Comm 81.77
# (BackTest pid=40350) 2014-10-08, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2014-10-09, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2014-10-28, SELL EXECUTED, Price: 9.92, Cost: 408834.00, Comm 79.76
# (BackTest pid=40350) 2014-10-28, OPERATION PROFIT, GROSS -10050.00, NET -10211.52
# (BackTest pid=40350) 2014-10-31, BUY EXECUTED, Price: 10.58, Cost: 289892.00, Comm 57.98
# (BackTest pid=40350) 2014-11-03, BUY EXECUTED, Price: 11.40, Cost: 258780.00, Comm 51.76
# (BackTest pid=40350) 2014-11-11, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2014-11-12, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2014-11-19, SELL EXECUTED, Price: 10.91, Cost: 548672.00, Comm 109.32
# (BackTest pid=40350) 2014-11-19, OPERATION PROFIT, GROSS -2081.00, NET -2300.05
# (BackTest pid=40350) 2014-12-01, BUY EXECUTED, Price: 13.55, Cost: 177505.00, Comm 35.50
# (BackTest pid=40350) 2014-12-03, BUY EXECUTED, Price: 13.80, Cost: 157320.00, Comm 31.46
# (BackTest pid=40350) 2014-12-05, BUY EXECUTED, Price: 14.29, Cost: 147187.00, Comm 29.44
# (BackTest pid=40350) 2014-12-18, BUY EXECUTED, Price: 15.50, Cost: 111600.00, Comm 22.32
# (BackTest pid=40350) 2015-01-20, SELL EXECUTED, Price: 13.60, Cost: 593612.00, Comm 114.24
# (BackTest pid=40350) 2015-01-20, OPERATION PROFIT, GROSS -22412.00, NET -22644.96
# (BackTest pid=40350) 2015-03-10, BUY EXECUTED, Price: 15.73, Cost: 228085.00, Comm 45.62
# (BackTest pid=40350) 2015-03-12, BUY EXECUTED, Price: 16.41, Cost: 216612.00, Comm 43.32
# (BackTest pid=40350) 2015-03-13, BUY EXECUTED, Price: 17.20, Cost: 204680.00, Comm 40.94
# (BackTest pid=40350) 2015-03-16, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2015-03-17, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2015-05-06, SELL EXECUTED, Price: 18.35, Cost: 649377.00, Comm 145.33
# (BackTest pid=40350) 2015-05-06, OPERATION PROFIT, GROSS 77283.00, NET 77007.79
# (BackTest pid=40350) 2015-06-04, BUY EXECUTED, Price: 21.00, Cost: 170100.00, Comm 34.02
# (BackTest pid=40350) 2015-06-05, BUY EXECUTED, Price: 22.68, Cost: 161028.00, Comm 32.21
# (BackTest pid=40350) 2015-06-09, BUY EXECUTED, Price: 23.80, Cost: 149940.00, Comm 29.99
# (BackTest pid=40350) 2015-06-19, SELL EXECUTED, Price: 20.24, Cost: 481068.00, Comm 87.03
# (BackTest pid=40350) 2015-06-19, OPERATION PROFIT, GROSS -45908.00, NET -46091.25
# (BackTest pid=40350) 2015-10-13, BUY EXECUTED, Price: 12.25, Cost: 218050.00, Comm 43.61
# (BackTest pid=40350) 2015-10-19, BUY EXECUTED, Price: 12.58, Cost: 247826.00, Comm 49.57
# (BackTest pid=40350) 2015-10-21, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2015-10-22, BUY EXECUTED, Price: 12.73, Cost: 230413.00, Comm 46.08
# (BackTest pid=40350) 2015-10-23, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2015-11-30, SELL EXECUTED, Price: 14.28, Cost: 696289.00, Comm 158.79
# (BackTest pid=40350) 2015-11-30, OPERATION PROFIT, GROSS 97679.00, NET 97380.95
# (BackTest pid=40350) 2016-03-07, BUY EXECUTED, Price: 13.20, Cost: 217800.00, Comm 43.56
# (BackTest pid=40350) 2016-03-22, BUY EXECUTED, Price: 13.75, Cost: 244750.00, Comm 48.95
# (BackTest pid=40350) 2016-04-18, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2016-04-29, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2016-05-03, BUY EXECUTED, Price: 14.09, Cost: 350841.00, Comm 70.17
# (BackTest pid=40350) 2016-09-13, SELL EXECUTED, Price: 16.01, Cost: 813391.00, Comm 189.56
# (BackTest pid=40350) 2016-09-13, OPERATION PROFIT, GROSS 134401.00, NET 134048.76
# (BackTest pid=40350) 2016-10-24, BUY EXECUTED, Price: 16.45, Cost: 651420.00, Comm 130.28
# (BackTest pid=40350) 2016-10-25, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2016-10-26, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2016-10-28, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2016-10-31, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 
# (BackTest pid=29855, ip=100.64.248.190) 2019-02-14, BUY EXECUTED, Price: 5.43, Cost: 481641.00, Comm 96.33
# (BackTest pid=29855, ip=100.64.248.190) 2019-02-19, Order Canceled/Margin/Rejected
# (BackTest pid=29855, ip=100.64.248.190) 2019-02-20, BUY EXECUTED, Price: 5.54, Cost: 391124.00, Comm 78.22
# (BackTest pid=29855, ip=100.64.248.190) 2019-02-25, Order Canceled/Margin/Rejected
# (BackTest pid=29855, ip=100.64.248.190) 2019-02-26, Order Canceled/Margin/Rejected
# (BackTest pid=29855, ip=100.64.248.190) 2019-03-27, SELL EXECUTED, Price: 6.15, Cost: 872765.00, Comm 195.94
# (BackTest pid=29855, ip=100.64.248.190) 2019-03-27, OPERATION PROFIT, GROSS 106930.00, NET 106559.51
# (BackTest pid=29855, ip=100.64.248.190) 2019-06-21, BUY EXECUTED, Price: 4.85, Cost: 529135.00, Comm 105.83
# (BackTest pid=29855, ip=100.64.248.190) 2019-07-09, SELL EXECUTED, Price: 4.58, Cost: 529135.00, Comm 99.94
# (BackTest pid=29855, ip=100.64.248.190) 2019-07-09, OPERATION PROFIT, GROSS -29457.00, NET -29662.76
# (BackTest pid=40350) 2017-01-19, BUY EXECUTED, Price: 17.75, Cost: 473925.00, Comm 94.78
# (BackTest pid=40350) 2017-02-14, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2017-02-15, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2017-02-16, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2017-02-17, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2017-03-10, SELL EXECUTED, Price: 17.95, Cost: 473925.00, Comm 95.85
# (BackTest pid=40350) 2017-03-10, OPERATION PROFIT, GROSS 5340.00, NET 5149.36
# (BackTest pid=40350) 2017-05-15, BUY EXECUTED, Price: 17.82, Cost: 390258.00, Comm 78.05
# (BackTest pid=40350) 2017-05-26, BUY EXECUTED, Price: 18.25, Cost: 377775.00, Comm 75.56
# (BackTest pid=40350) 2017-06-21, SELL EXECUTED, Price: 17.59, Cost: 768033.00, Comm 149.87
# (BackTest pid=40350) 2017-06-21, OPERATION PROFIT, GROSS -18699.00, NET -19002.47
# (BackTest pid=40350) 2017-06-28, BUY EXECUTED, Price: 18.90, Cost: 457380.00, Comm 91.48
# (BackTest pid=40350) 2017-06-29, BUY EXECUTED, Price: 19.52, Cost: 404064.00, Comm 80.81
# (BackTest pid=40350) 2017-06-30, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2017-07-06, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2017-07-07, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2017-07-12, SELL EXECUTED, Price: 15.10, Cost: 861444.00, Comm 135.60
# (BackTest pid=40350) 2017-07-12, OPERATION PROFIT, GROSS -183454.00, NET -183761.89
# (BackTest pid=40350) 2017-10-17, BUY EXECUTED, Price: 16.63, Cost: 419076.00, Comm 83.82
# (BackTest pid=40350) 2017-10-19, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2017-10-30, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2017-10-31, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2017-11-01, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2017-12-08, SELL EXECUTED, Price: 17.19, Cost: 419076.00, Comm 86.64
# (BackTest pid=40350) 2017-12-08, OPERATION PROFIT, GROSS 14112.00, NET 13941.55
# (BackTest pid=40350) 2018-01-03, BUY EXECUTED, Price: 18.46, Cost: 358124.00, Comm 71.62
# (BackTest pid=40350) 2018-01-16, BUY EXECUTED, Price: 19.10, Cost: 311330.00, Comm 62.27
# (BackTest pid=40350) 2018-01-17, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2018-01-18, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2018-01-19, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2018-02-12, SELL EXECUTED, Price: 18.81, Cost: 669454.00, Comm 134.30
# (BackTest pid=40350) 2018-02-12, OPERATION PROFIT, GROSS 2063.00, NET 1794.81
# (BackTest pid=40350) 2018-08-01, BUY EXECUTED, Price: 17.47, Cost: 314460.00, Comm 62.89
# (BackTest pid=40350) 2018-08-16, SELL EXECUTED, Price: 16.30, Cost: 314460.00, Comm 58.68
# (BackTest pid=40350) 2018-08-16, OPERATION PROFIT, GROSS -21060.00, NET -21181.57
# (BackTest pid=40350) 2018-09-25, BUY EXECUTED, Price: 17.34, Cost: 319056.00, Comm 63.81
# (BackTest pid=40350) 2018-09-27, BUY EXECUTED, Price: 17.63, Cost: 349074.00, Comm 69.81
# (BackTest pid=40350) 2018-10-12, SELL EXECUTED, Price: 16.55, Cost: 668130.00, Comm 126.44
# (BackTest pid=40350) 2018-10-12, OPERATION PROFIT, GROSS -35920.00, NET -36180.07
# (BackTest pid=40350) 2018-11-05, BUY EXECUTED, Price: 18.10, Cost: 197290.00, Comm 39.46
# (BackTest pid=40350) 2018-11-15, SELL EXECUTED, Price: 16.85, Cost: 197290.00, Comm 36.73
# (BackTest pid=40350) 2018-11-15, OPERATION PROFIT, GROSS -13625.00, NET -13701.19
# (BackTest pid=40350) 2019-01-21, BUY EXECUTED, Price: 16.80, Cost: 393120.00, Comm 78.62
# (BackTest pid=40350) 2019-01-25, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2019-01-28, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2019-01-29, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2019-01-30, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2019-04-23, SELL EXECUTED, Price: 22.70, Cost: 393120.00, Comm 106.24
# (BackTest pid=40350) 2019-04-23, OPERATION PROFIT, GROSS 138060.00, NET 137875.14
# (BackTest pid=40350) 2019-05-29, BUY EXECUTED, Price: 23.29, Cost: 279480.00, Comm 55.90
# (BackTest pid=40350) 2019-06-10, SELL EXECUTED, Price: 22.00, Cost: 279480.00, Comm 52.80
# (BackTest pid=40350) 2019-06-10, OPERATION PROFIT, GROSS -15480.00, NET -15588.70
# (BackTest pid=40350) 2019-06-21, BUY EXECUTED, Price: 24.09, Cost: 315579.00, Comm 63.12
# (BackTest pid=40350) 2019-07-02, BUY EXECUTED, Price: 24.93, Cost: 336555.00, Comm 67.31
# (BackTest pid=40350) 2019-07-09, SELL EXECUTED, Price: 23.28, Cost: 652134.00, Comm 123.85
# (BackTest pid=40350) 2019-07-09, OPERATION PROFIT, GROSS -32886.00, NET -33140.28
# (BackTest pid=40350) 2019-09-06, BUY EXECUTED, Price: 24.40, Cost: 307440.00, Comm 61.49
# (BackTest pid=40350) 2019-09-16, BUY EXECUTED, Price: 24.85, Cost: 335475.00, Comm 67.10
# (BackTest pid=40350) 2019-09-27, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2019-09-30, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2019-10-08, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2019-11-25, SELL EXECUTED, Price: 27.51, Cost: 642915.00, Comm 143.60
# (BackTest pid=40350) 2019-11-25, OPERATION PROFIT, GROSS 75096.00, NET 74823.81
# (BackTest pid=40350) 2020-01-03, BUY EXECUTED, Price: 29.03, Cost: 374487.00, Comm 74.90
# (BackTest pid=40350) 2020-01-08, BUY EXECUTED, Price: 29.16, Cost: 399492.00, Comm 79.90
# (BackTest pid=40350) 2020-01-10, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2020-01-22, SELL EXECUTED, Price: 27.66, Cost: 773979.00, Comm 147.15
# ...
# (BackTest pid=40350) 2019-09-12, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2019-09-16, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2019-09-24, SELL EXECUTED, Price: 5.67, Cost: 808044.00, Comm 158.53
# (BackTest pid=40350) 2019-09-24, OPERATION PROFIT, GROSS -15378.00, NET -15698.14
# (BackTest pid=40350) 2019-10-14, BUY EXECUTED, Price: 6.01, Cost: 603404.00, Comm 120.68
# (BackTest pid=40350) 2019-10-15, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2019-10-16, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2019-10-22, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2019-10-23, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2019-11-21, SELL EXECUTED, Price: 5.99, Cost: 603404.00, Comm 120.28
# (BackTest pid=40350) 2019-11-21, OPERATION PROFIT, GROSS -2008.00, NET -2248.96
# (BackTest pid=40350) 2019-12-18, BUY EXECUTED, Price: 6.20, Cost: 733460.00, Comm 146.69
# (BackTest pid=40350) 2020-01-16, SELL EXECUTED, Price: 6.03, Cost: 733460.00, Comm 142.67
# (BackTest pid=40350) 2020-01-16, OPERATION PROFIT, GROSS -20111.00, NET -20400.36
# (BackTest pid=40350) 2020-06-30, BUY EXECUTED, Price: 5.21, Cost: 752845.00, Comm 150.57
# (BackTest pid=40350) 2020-07-02, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2020-07-03, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2020-07-06, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2020-07-07, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2020-07-20, SELL EXECUTED, Price: 5.25, Cost: 752845.00, Comm 151.73
# (BackTest pid=40350) 2020-07-20, OPERATION PROFIT, GROSS 5780.00, NET 5477.71
# (BackTest pid=40350) 2020-08-18, BUY EXECUTED, Price: 5.47, Cost: 509804.00, Comm 101.96
# (BackTest pid=40350) 2020-08-26, SELL EXECUTED, Price: 5.25, Cost: 509804.00, Comm 97.86
# (BackTest pid=40350) 2020-08-26, OPERATION PROFIT, GROSS -20504.00, NET -20703.82
# (BackTest pid=40350) 2020-10-19, BUY EXECUTED, Price: 5.30, Cost: 687410.00, Comm 137.48
# (BackTest pid=40350) 2020-10-29, SELL EXECUTED, Price: 5.08, Cost: 687410.00, Comm 131.78
# (BackTest pid=40350) 2020-10-29, OPERATION PROFIT, GROSS -28534.00, NET -28803.26
# (BackTest pid=40350) 2020-11-30, BUY EXECUTED, Price: 5.51, Cost: 560918.00, Comm 112.18
# (BackTest pid=40350) 2020-12-01, SELL EXECUTED, Price: 5.27, Cost: 560918.00, Comm 107.30
# (BackTest pid=40350) 2020-12-01, OPERATION PROFIT, GROSS -24432.00, NET -24651.48
# (BackTest pid=40350) 2021-01-15, BUY EXECUTED, Price: 5.17, Cost: 838057.00, Comm 167.61
# (BackTest pid=40350) 2021-01-28, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2021-02-01, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2021-02-02, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2021-02-03, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2021-03-03, SELL EXECUTED, Price: 5.11, Cost: 838057.00, Comm 165.67
# (BackTest pid=40350) 2021-03-03, OPERATION PROFIT, GROSS -9726.00, NET -10059.28
# (BackTest pid=40350) 2021-03-17, BUY EXECUTED, Price: 5.46, Cost: 446082.00, Comm 89.22
# (BackTest pid=40350) 2021-04-26, SELL EXECUTED, Price: 5.33, Cost: 446082.00, Comm 87.09
# (BackTest pid=40350) 2021-04-26, OPERATION PROFIT, GROSS -10621.00, NET -10797.31
# (BackTest pid=40350) 2021-09-13, BUY EXECUTED, Price: 4.79, Cost: 583901.00, Comm 116.78
# (BackTest pid=40350) 2021-09-14, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2021-09-22, SELL EXECUTED, Price: 4.52, Cost: 583901.00, Comm 110.20
# (BackTest pid=40350) 2021-09-22, OPERATION PROFIT, GROSS -32913.00, NET -33139.98
# (BackTest pid=40350) 2021-12-10, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2021-12-24, BUY EXECUTED, Price: 4.62, Cost: 833448.00, Comm 166.69
# (BackTest pid=40350) 2022-01-06, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-01-10, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-01-11, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-01-12, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-02-25, SELL EXECUTED, Price: 4.62, Cost: 833448.00, Comm 166.69
# (BackTest pid=40350) 2022-02-25, OPERATION PROFIT, GROSS 0.00, NET -333.38
# (BackTest pid=40350) 2022-03-29, BUY EXECUTED, Price: 4.87, Cost: 327751.00, Comm 65.55
# (BackTest pid=40350) 2022-03-31, BUY EXECUTED, Price: 5.08, Cost: 301752.00, Comm 60.35
# (BackTest pid=40350) 2022-04-06, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-04-07, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-04-26, SELL EXECUTED, Price: 4.91, Cost: 629503.00, Comm 124.42
# (BackTest pid=40350) 2022-04-26, OPERATION PROFIT, GROSS -7406.00, NET -7656.32
# (BackTest pid=40350) 2022-06-10, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-06-16, BUY EXECUTED, Price: 4.83, Cost: 637077.00, Comm 127.42
# (BackTest pid=40350) 2022-07-07, SELL EXECUTED, Price: 4.72, Cost: 637077.00, Comm 124.51
# (BackTest pid=40350) 2022-07-07, OPERATION PROFIT, GROSS -14509.00, NET -14760.93
# (BackTest pid=40350) 2022-08-30, BUY EXECUTED, Price: 4.43, Cost: 664943.00, Comm 132.99
# (BackTest pid=40350) 2022-08-31, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-09-01, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-09-02, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-09-05, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-10-26, SELL EXECUTED, Price: 4.47, Cost: 664943.00, Comm 134.19
# (BackTest pid=40350) 2022-10-26, OPERATION PROFIT, GROSS 6004.00, NET 5736.82
# (BackTest pid=40350) 2022-11-24, BUY EXECUTED, Price: 4.97, Cost: 337463.00, Comm 67.49
# (BackTest pid=40350) 2022-11-28, BUY EXECUTED, Price: 4.97, Cost: 319074.00, Comm 63.81
# (BackTest pid=40350) 2022-11-30, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-12-06, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-12-07, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-12-21, SELL EXECUTED, Price: 4.92, Cost: 656537.00, Comm 129.99
# (BackTest pid=40350) 2022-12-21, OPERATION PROFIT, GROSS -6605.00, NET -6866.29
# (BackTest pid=40350) 2022-12-27, (MA Period 15) Ending Value 813737.85
# (BackTest pid=40350) Final Portfolio Value: 813737.85
# (BackTest pid=40350) Starting Portfolio Value: 1000000.00
# (BackTest pid=40350) 2017-02-16, BUY EXECUTED, Price: 16.18, Cost: 244318.00, Comm 48.86
# (BackTest pid=40350) 2017-02-17, BUY EXECUTED, Price: 16.30, Cost: 228200.00, Comm 45.64
# (BackTest pid=40350) 2017-02-21, BUY EXECUTED, Price: 19.11, Cost: 217854.00, Comm 43.57
# (BackTest pid=40350) 2017-02-24, SELL EXECUTED, Price: 16.70, Cost: 690372.00, Comm 135.27
# (BackTest pid=40350) 2017-02-24, OPERATION PROFIT, GROSS -14022.00, NET -14295.34
# (BackTest pid=40350) 2017-03-10, BUY EXECUTED, Price: 19.72, Cost: 128180.00, Comm 25.64
# (BackTest pid=40350) 2017-03-23, SELL EXECUTED, Price: 17.85, Cost: 128180.00, Comm 23.21
# (BackTest pid=40350) 2017-03-23, OPERATION PROFIT, GROSS -12155.00, NET -12203.84
# (BackTest pid=40350) 2017-05-05, BUY EXECUTED, Price: 19.90, Cost: 177110.00, Comm 35.42
# (BackTest pid=40350) 2017-05-11, BUY EXECUTED, Price: 20.75, Cost: 149400.00, Comm 29.88
# (BackTest pid=40350) 2017-05-19, SELL EXECUTED, Price: 16.71, Cost: 326510.00, Comm 53.81
# (BackTest pid=40350) 2017-05-19, OPERATION PROFIT, GROSS -57479.00, NET -57598.11
# (BackTest pid=40350) 2017-08-29, BUY EXECUTED, Price: 11.80, Cost: 363440.00, Comm 72.69
# (BackTest pid=40350) 2017-09-01, BUY EXECUTED, Price: 11.99, Cost: 354904.00, Comm 70.98
# (BackTest pid=40350) 2017-09-04, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2017-09-22, SELL EXECUTED, Price: 11.47, Cost: 718344.00, Comm 138.56
# (BackTest pid=40350) 2017-09-22, OPERATION PROFIT, GROSS -25556.00, NET -25838.23
# (BackTest pid=40350) 2018-01-05, BUY EXECUTED, Price: 8.60, Cost: 325940.00, Comm 65.19
# (BackTest pid=40350) 2018-01-18, BUY EXECUTED, Price: 8.72, Cost: 317408.00, Comm 63.48
# (BackTest pid=40350) 2018-01-19, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2018-01-22, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2018-01-23, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2018-02-05, SELL EXECUTED, Price: 8.40, Cost: 643348.00, Comm 124.82
# (BackTest pid=40350) 2018-02-05, OPERATION PROFIT, GROSS -19228.00, NET -19481.49
# (BackTest pid=40350) 2018-05-23, BUY EXECUTED, Price: 7.60, Cost: 575320.00, Comm 115.06
# (BackTest pid=40350) 2018-05-29, SELL EXECUTED, Price: 7.35, Cost: 575320.00, Comm 111.28
# (BackTest pid=40350) 2018-05-29, OPERATION PROFIT, GROSS -18925.00, NET -19151.34
# (BackTest pid=40350) 2018-07-23, BUY EXECUTED, Price: 6.35, Cost: 313690.00, Comm 62.74
# (BackTest pid=40350) 2018-07-24, BUY EXECUTED, Price: 6.42, Cost: 275418.00, Comm 55.08
# (BackTest pid=40350) 2018-08-01, BUY EXECUTED, Price: 6.59, Cost: 252397.00, Comm 50.48
# (BackTest pid=40350) 2018-08-20, SELL EXECUTED, Price: 6.05, Cost: 841505.00, Comm 158.03
# (BackTest pid=40350) 2018-08-20, OPERATION PROFIT, GROSS -51375.00, NET -51701.33
# (BackTest pid=40350) 2018-10-26, BUY EXECUTED, Price: 6.48, Cost: 197640.00, Comm 39.53
# (BackTest pid=40350) 2018-11-05, BUY EXECUTED, Price: 6.57, Cost: 177390.00, Comm 35.48
# (BackTest pid=40350) 2018-11-19, BUY EXECUTED, Price: 6.73, Cost: 241607.00, Comm 48.32
# (BackTest pid=40350) 2018-11-20, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2018-11-30, SELL EXECUTED, Price: 6.28, Cost: 616637.00, Comm 117.31
# (BackTest pid=40350) 2018-11-30, OPERATION PROFIT, GROSS -30085.00, NET -30325.64
# (BackTest pid=40350) 2019-01-30, BUY EXECUTED, Price: 6.76, Cost: 352872.00, Comm 70.57
# (BackTest pid=40350) 2019-02-13, BUY EXECUTED, Price: 6.85, Cost: 319895.00, Comm 63.98
# (BackTest pid=40350) 2019-02-14, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2019-02-15, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2019-02-19, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2019-03-15, SELL EXECUTED, Price: 7.68, Cost: 672767.00, Comm 151.91
# (BackTest pid=40350) 2019-03-15, OPERATION PROFIT, GROSS 86785.00, NET 86498.54
# (BackTest pid=40350) 2019-09-05, BUY EXECUTED, Price: 5.31, Cost: 578259.00, Comm 115.65
# (BackTest pid=40350) 2019-09-06, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2019-09-09, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2019-09-10, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2019-09-11, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2019-09-24, SELL EXECUTED, Price: 5.27, Cost: 578259.00, Comm 114.78
# (BackTest pid=40350) 2019-09-24, OPERATION PROFIT, GROSS -4356.00, NET -4586.43
# (BackTest pid=40350) 2019-10-15, BUY EXECUTED, Price: 5.55, Cost: 355200.00, Comm 71.04
# (BackTest pid=40350) 2019-11-01, SELL EXECUTED, Price: 5.24, Cost: 355200.00, Comm 67.07
# (BackTest pid=40350) 2019-11-01, OPERATION PROFIT, GROSS -19840.00, NET -19978.11
# (BackTest pid=40350) 2019-12-17, BUY EXECUTED, Price: 5.08, Cost: 798576.00, Comm 159.72
# (BackTest pid=40350) 2019-12-18, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2019-12-19, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2019-12-20, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2019-12-23, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2020-01-17, SELL EXECUTED, Price: 5.19, Cost: 798576.00, Comm 163.17
# (BackTest pid=40350) 2020-01-17, OPERATION PROFIT, GROSS 17292.00, NET 16969.11
# (BackTest pid=40350) 2020-03-06, BUY EXECUTED, Price: 4.95, Cost: 292050.00, Comm 58.41
# (BackTest pid=40350) 2020-03-19, SELL EXECUTED, Price: 4.53, Cost: 292050.00, Comm 53.45
# (BackTest pid=40350) 2020-03-19, OPERATION PROFIT, GROSS -24780.00, NET -24891.86
# (BackTest pid=40350) 2020-06-29, BUY EXECUTED, Price: 4.49, Cost: 680684.00, Comm 136.14
# (BackTest pid=40350) 2020-07-06, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2020-07-07, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2020-07-08, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2020-07-09, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2020-07-27, SELL EXECUTED, Price: 4.66, Cost: 680684.00, Comm 141.29
# (BackTest pid=40350) 2020-07-27, OPERATION PROFIT, GROSS 25772.00, NET 25494.57
# (BackTest pid=40350) 2020-11-20, BUY EXECUTED, Price: 4.94, Cost: 402116.00, Comm 80.42
# (BackTest pid=40350) 2020-11-30, BUY EXECUTED, Price: 5.11, Cost: 388871.00, Comm 77.77
# (BackTest pid=40350) 2020-12-02, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2020-12-03, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2020-12-04, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2020-12-14, SELL EXECUTED, Price: 4.94, Cost: 790987.00, Comm 155.61
# (BackTest pid=40350) 2020-12-14, OPERATION PROFIT, GROSS -12937.00, NET -13250.81
# (BackTest pid=40350) 2021-07-07, BUY EXECUTED, Price: 4.67, Cost: 520238.00, Comm 104.05
# (BackTest pid=40350) 2021-07-21, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2021-07-22, BUY EXECUTED, Price: 4.74, Cost: 310944.00, Comm 62.19
# (BackTest pid=40350) 2021-08-12, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2021-08-13, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2021-08-31, SELL EXECUTED, Price: 4.77, Cost: 831182.00, Comm 168.86
# (BackTest pid=40350) 2021-08-31, OPERATION PROFIT, GROSS 13108.00, NET 12772.91
# (BackTest pid=40350) 2021-09-08, BUY EXECUTED, Price: 5.17, Cost: 390852.00, Comm 78.17
# (BackTest pid=40350) 2021-09-13, BUY EXECUTED, Price: 5.23, Cost: 390681.00, Comm 78.14
# (BackTest pid=40350) 2021-09-14, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2021-09-16, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2021-09-17, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2021-11-08, SELL EXECUTED, Price: 4.85, Cost: 781533.00, Comm 145.79
# (BackTest pid=40350) 2021-11-08, OPERATION PROFIT, GROSS -52578.00, NET -52880.10
# (BackTest pid=40350) 2022-01-10, BUY EXECUTED, Price: 5.07, Cost: 376194.00, Comm 75.24
# (BackTest pid=40350) 2022-01-11, BUY EXECUTED, Price: 5.28, Cost: 344256.00, Comm 68.85
# (BackTest pid=40350) 2022-01-13, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-01-14, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-01-19, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-02-25, SELL EXECUTED, Price: 5.39, Cost: 720450.00, Comm 150.27
# (BackTest pid=40350) 2022-02-25, OPERATION PROFIT, GROSS 30916.00, NET 30621.64
# (BackTest pid=40350) 2022-04-07, BUY EXECUTED, Price: 5.85, Cost: 238095.00, Comm 47.62
# (BackTest pid=40350) 2022-04-27, SELL EXECUTED, Price: 5.12, Cost: 238095.00, Comm 41.68
# (BackTest pid=40350) 2022-04-27, OPERATION PROFIT, GROSS -29711.00, NET -29800.30
# (BackTest pid=40350) 2022-06-16, BUY EXECUTED, Price: 5.20, Cost: 331240.00, Comm 66.25
# (BackTest pid=40350) 2022-07-08, BUY EXECUTED, Price: 5.30, Cost: 429830.00, Comm 85.97
# (BackTest pid=40350) 2022-07-11, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-07-12, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-07-13, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-08-03, SELL EXECUTED, Price: 5.09, Cost: 761070.00, Comm 147.41
# (BackTest pid=40350) 2022-08-03, OPERATION PROFIT, GROSS -24038.00, NET -24337.62
# (BackTest pid=40350) 2022-09-02, BUY EXECUTED, Price: 5.28, Cost: 363264.00, Comm 72.65
# (BackTest pid=40350) 2022-09-09, BUY EXECUTED, Price: 5.34, Cost: 363120.00, Comm 72.62
# (BackTest pid=40350) 2022-09-13, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-09-14, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-09-21, SELL EXECUTED, Price: 5.18, Cost: 726384.00, Comm 141.72
# (BackTest pid=40350) 2022-09-21, OPERATION PROFIT, GROSS -17760.00, NET -18047.00
# (BackTest pid=40350) 2022-11-28, BUY EXECUTED, Price: 4.70, Cost: 399970.00, Comm 79.99
# (BackTest pid=40350) 2022-11-30, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-12-01, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-12-05, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-12-06, Order Canceled/Margin/Rejected
# (BackTest pid=40350) 2022-12-20, SELL EXECUTED, Price: 4.68, Cost: 399970.00, Comm 79.65
# (BackTest pid=40350) 2022-12-20, OPERATION PROFIT, GROSS -1702.00, NET -1861.65
# (BackTest pid=40350) 2022-12-27, (MA Period 15) Ending Value 752127.56
# (BackTest pid=40350) Final Portfolio Value: 752127.56

# %%
# 开始计时
start_time = time.time()

for line in open(txtname):  
    code = line[:6]
    stock_list.append(code)


# 分布式回测
backtest_tasks = [BackTest.remote(code) for code in stock_list]
results = ray.get(backtest_tasks)

# 结束计时
end_time = time.time()  

# 计算执行时间
execution_time = end_time - start_time

print(f"计算执行时间为: {execution_time}秒")

# 关闭Ray集群
ray.shutdown()
# Out:
# 计算执行时间为: 13.649070024490356秒
